# %%
#Process Name : Data Collection & Data Preprocessing.pandas is a python library which is used for data handling and transformation
import pandas as pd 
#print(dir(pd))

# %%
#read_csv is a fucntion inside pandas which will read/load the comma separated data.
data=pd.read_csv("insurance_pre.csv") 
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Using Ordinal Encoder to convert categorical value to number
from sklearn.preprocessing import OrdinalEncoder  
data['sex'] = OrdinalEncoder().fit_transform(data[['sex']])
data['smoker'] = OrdinalEncoder().fit_transform(data[['smoker']])
data
# Out:
#       age  sex     bmi  children  smoker      charges
# 0      19  0.0  27.900         0     1.0  16884.92400
# 1      18  1.0  33.770         1     0.0   1725.55230
# 2      28  1.0  33.000         3     0.0   4449.46200
# 3      33  1.0  22.705         0     0.0  21984.47061
# 4      32  1.0  28.880         0     0.0   3866.85520
# ...   ...  ...     ...       ...     ...          ...
# 1333   50  1.0  30.970         3     0.0  10600.54830
# 1334   18  0.0  31.920         0     0.0   2205.98080
# 1335   18  0.0  36.850         0     0.0   1629.83350
# 1336   21  0.0  25.800         0     0.0   2007.94500
# 1337   61  0.0  29.070         0     1.0  29141.36030
#
# [1338 rows x 6 columns]

# %%
#Process Name : Input Output Split
independent=data[['age', 'sex', 'bmi', 'children', 'smoker']] #Assigning the dataset column to independent which is input
dependent=data[['charges']]#Assigning the dataset column to dependent which is output/target

# %%
#Process Name : Train Test Split
from sklearn.model_selection import train_test_split #sklearn is a library where all ML algorithms are present.Here we are importing function called train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent, dependent, test_size=0.3, random_state=0) #Splitting the dataset in to test and train.test set being 30%(0.3)

# %%
#Process Name:Standard Scalar
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# Multiple Linear Regression Model

# %%
#Process Name : Model Creation
#Importing/Creating Linear Regression Model
#from sklearn.linear_model import LinearRegression
#Model=LinearRegression()
#Model.fit(X_train,Y_train) #giving the training set to the model

# %%
#Finding weight(m/slope) and bias(c/origin/intercept) y=mx+c
#weight=Model.coef_
#print("The slope of the model is : ",weight)
#bias=Model.intercept_
#print("The intercept of the model is : ",bias)

# %% [markdown]
# Support Vector Machine Model

# %%
#Process Name : Model Creation
#Importing/Creating Linear Regression Model
#from sklearn.svm import SVR
#Model=SVR(kernel="linear",C=3000)
#Model.fit(X_train,Y_train) #giving the training set to the model

# %% [markdown]
# Decision Tree Model

# %%
#Process Name : Model Creation
#Importing/Creating Decision tree model
#from sklearn.tree import DecisionTreeRegressor
#Model=DecisionTreeRegressor(criterion='poisson', max_features='log2',splitter='best', min_samples_split=3,max_depth=5)
#Model.fit(X_train,Y_train) #giving the training set to the model

# %% [markdown]
# Random Forest Model

# %%
#Process Name : Model Creation
#Importing/Creating Random Forest model
from sklearn.ensemble import RandomForestRegressor
Model=RandomForestRegressor(n_estimators=1000,max_depth=5,min_samples_leaf=3)
Model.fit(X_train,Y_train) #giving the training set to the model
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=5, min_samples_leaf=3, n_estimators=1000)

# %%
#Process Name : Prediction
Y_predicted=Model.predict(X_test)

# %%
#Process Name : Evaluation metrics
from sklearn.metrics import r2_score  #r2_score fucntion in sklearn is used to evaluate model
r_score=r2_score(Y_test,Y_predicted)
print("r_score/accuracy is :",r_score)
# Out:
# r_score/accuracy is : 0.8913137684485724

# %%
#Process Name : Saving the model
import pickle 
filename="insurance_prediction_regression_model.sav"  #model is saved in the filename
pickle.dump(Model,open(filename,'wb')) #assigning the model to this file given as write binary
